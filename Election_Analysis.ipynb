# %% [markdown]
# <a href="https://colab.research.google.com/github/muthukumar41-dev/muthukumar/blob/main/Election_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [link text](https://)**1.1) Read the dataset.** Do the descriptive statistics and do null value condition check.

# %% [markdown]
# Descriptive Analysis of Dataset

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datastructure /Datasets/MP Election TN(2019-1991).csv')
df.head()
# Out:
#    State_Name  Assembly_No  Constituency_No  Year  month  Poll_No  DelimID  \
# 0  Tamil_Nadu           17                1  2019    4.0        0        4
# 1  Tamil_Nadu           17                1  2019    4.0        0        4
# 2  Tamil_Nadu           17                1  2019    4.0        0        4
# 3  Tamil_Nadu           17                1  2019    4.0        0        4
# 4  Tamil_Nadu           17                1  2019    4.0        0        4
#
#    Position       Candidate Sex  ... No_Terms  Turncoat Incumbent  Recontest  \
# 0         1  Dr.K.Jayakumar   M  ...      1.0     False     False       True
# 1         2  Dr.P.Venugopal   M  ...      2.0     False      True       True
# 2         3    Logarangan.M   M  ...      0.0     False     False      False
# 3         4    M.VETRISELVI   F  ...      0.0     False     False      False
# 4         5        Pon.Raja   M  ...      0.0     False     False      False
#
#         MyNeta_education                      TCPD_Prof_Main  \
# 0              Doctorate                         Agriculture
# 1  Graduate Professional  Liberal Profession or Professional
# 2          Post Graduate  Liberal Profession or Professional
# 3  Graduate Professional                               Other
# 4  Graduate Professional                         Agriculture
#
#   TCPD_Prof_Main_Desc  TCPD_Prof_Second  TCPD_Prof_Second_Desc  \
# 0                 NaN               NaN                    NaN
# 1              Doctor          Politics                     MP
# 2              Doctor       Social Work               Activist
# 3           Household               NaN                    NaN
# 4                 NaN               NaN                    NaN
#
#              Election_Type
# 0  Lok Sabha Election (GE)
# 1  Lok Sabha Election (GE)
# 2  Lok Sabha Election (GE)
# 3  Lok Sabha Election (GE)
# 4  Lok Sabha Election (GE)
#
# [5 rows x 45 columns]

# %%
df.describe(include = "all")
# Out:
#         State_Name  Assembly_No  Constituency_No         Year        month  \
# count         6446  6446.000000      6446.000000  6446.000000  6308.000000
# unique           1          NaN              NaN          NaN          NaN
# top     Tamil_Nadu          NaN              NaN          NaN          NaN
# freq          6446          NaN              NaN          NaN          NaN
# mean           NaN    12.673286        19.275520  2001.203227     4.979550
# std            NaN     3.417155        11.708369    12.835316     2.664662
# min            NaN     4.000000         1.000000  1967.000000     1.000000
# 25%            NaN    10.000000         8.000000  1991.000000     4.000000
# 50%            NaN    13.000000        20.000000  1999.000000     4.000000
# 75%            NaN    16.000000        29.000000  2014.000000     4.000000
# max            NaN    17.000000        39.000000  2021.000000    12.000000
#
#             Poll_No      DelimID     Position Candidate   Sex  ...  \
# count   6446.000000  6446.000000  6446.000000      6446  6306  ...
# unique          NaN          NaN          NaN      6051     6  ...
# top             NaN          NaN          NaN      NOTA     M  ...
# freq            NaN          NaN          NaN        39  5969  ...
# mean       0.021409     3.385200    10.088272       NaN   NaN  ...
# std        0.144753     0.525021     8.261577       NaN   NaN  ...
# min        0.000000     2.000000     1.000000       NaN   NaN  ...
# 25%        0.000000     3.000000     4.000000       NaN   NaN  ...
# 50%        0.000000     3.000000     8.000000       NaN   NaN  ...
# 75%        0.000000     4.000000    14.000000       NaN   NaN  ...
# max        1.000000     4.000000    51.000000       NaN   NaN  ...
#
#            No_Terms  Turncoat Incumbent  Recontest  MyNeta_education  \
# count   6368.000000      6368      6368       6368              2317
# unique          NaN         2         2          2                11
# top             NaN     False     False      False     Post Graduate
# freq            NaN      6272      6092       5574               405
# mean       0.196294       NaN       NaN        NaN               NaN
# std        0.663698       NaN       NaN        NaN               NaN
# min        0.000000       NaN       NaN        NaN               NaN
# 25%        0.000000       NaN       NaN        NaN               NaN
# 50%        0.000000       NaN       NaN        NaN               NaN
# 75%        0.000000       NaN       NaN        NaN               NaN
# max        7.000000       NaN       NaN        NaN               NaN
#
#        TCPD_Prof_Main TCPD_Prof_Main_Desc  TCPD_Prof_Second  \
# count            2442                 797               127
# unique             17                  72                11
# top             Other              Lawyer       Agriculture
# freq              912                 204                44
# mean              NaN                 NaN               NaN
# std               NaN                 NaN               NaN
# min               NaN                 NaN               NaN
# 25%               NaN                 NaN               NaN
# 50%               NaN                 NaN               NaN
# 75%               NaN                 NaN               NaN
# max               NaN                 NaN               NaN
#
#         TCPD_Prof_Second_Desc            Election_Type
# count                      48                     6446
# unique                     23                        1
# top              Party Worker  Lok Sabha Election (GE)
# freq                       11                     6446
# mean                      NaN                      NaN
# std                       NaN                      NaN
# min                       NaN                      NaN
# 25%                       NaN                      NaN
# 50%                       NaN                      NaN
# 75%                       NaN                      NaN
# max                       NaN                      NaN
#
# [11 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6446 entries, 0 to 6445
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State_Name              6446 non-null   object
#  1   Assembly_No             6446 non-null   int64
#  2   Constituency_No         6446 non-null   int64
#  3   Year                    6446 non-null   int64
#  4   month                   6308 non-null   float64
#  5   Poll_No                 6446 non-null   int64
#  6   DelimID                 6446 non-null   int64
#  7   Position                6446 non-null   int64
#  8   Candidate               6446 non-null   object
#  9   Sex                     6306 non-null   object
#  10  Party                   6445 non-null   object
#  11  Votes                   6446 non-null   int64
#  12  Candidate_Type          2745 non-null   object
#  13  Valid_Votes             6446 non-null   int64
#  14  Electors                6437 non-null   float64
#  15  Constituency_Name       6446 non-null   object
#  16  Constituency_Type       6446 non-null   object
#  17  Sub_Region              0 non-null      float64
#  18  N_Cand                  6446 non-null   int64
#  19  Turnout_Percentage      6437 non-null   float64
#  20  Vote_Share_Percentage   6446 non-null   float64
#  21  Deposit_Lost            6368 non-null   object
#  22  Margin                  6446 non-null   int64
#  23  Margin_Percentage       6446 non-null   float64
#  24  ENOP                    6446 non-null   float64
#  25  pid                     6368 non-null   object
#  26  Party_Type_TCPD         6433 non-null   object
#  27  Party_ID                6433 non-null   float64
#  28  last_poll               6446 non-null   bool
#  29  Contested               6368 non-null   float64
#  30  Last_Party              1011 non-null   object
#  31  Last_Party_ID           1011 non-null   float64
#  32  Last_Constituency_Name  1011 non-null   object
#  33  Same_Constituency       1012 non-null   object
#  34  Same_Party              1012 non-null   object
#  35  No_Terms                6368 non-null   float64
#  36  Turncoat                6368 non-null   object
#  37  Incumbent               6368 non-null   object
#  38  Recontest               6368 non-null   object
#  39  MyNeta_education        2317 non-null   object
#  40  TCPD_Prof_Main          2442 non-null   object
#  41  TCPD_Prof_Main_Desc     797 non-null    object
#  42  TCPD_Prof_Second        127 non-null    object
#  43  TCPD_Prof_Second_Desc   48 non-null     object
#  44  Election_Type           6446 non-null   object
# dtypes: bool(1), float64(11), int64(10), object(23)
# memory usage: 2.2+ MB

# %% [markdown]
# Cleaning the dataset

# %%
df.fillna(0,inplace=True)

# %% [markdown]
# Check for missing value in any column

# %%
df.isnull().sum()
# Out:
# State_Name                0
# Assembly_No               0
# Constituency_No           0
# Year                      0
# month                     0
# Poll_No                   0
# DelimID                   0
# Position                  0
# Candidate                 0
# Sex                       0
# Party                     0
# Votes                     0
# Candidate_Type            0
# Valid_Votes               0
# Electors                  0
# Constituency_Name         0
# Constituency_Type         0
# Sub_Region                0
# N_Cand                    0
# Turnout_Percentage        0
# Vote_Share_Percentage     0
# Deposit_Lost              0
# Margin                    0
# Margin_Percentage         0
# ENOP                      0
# pid                       0
# Party_Type_TCPD           0
# Party_ID                  0
# last_poll                 0
# Contested                 0
# Last_Party                0
# Last_Party_ID             0
# Last_Constituency_Name    0
# Same_Constituency         0
# Same_Party                0
# No_Terms                  0
# Turncoat                  0
# Incumbent                 0
# Recontest                 0
# MyNeta_education          0
# TCPD_Prof_Main            0
# TCPD_Prof_Main_Desc       0
# TCPD_Prof_Second          0
# TCPD_Prof_Second_Desc     0
# Election_Type             0
# dtype: int64

# %% [markdown]
# **Label** Encoding

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Sex'] = df['Sex'].replace('NOTA','M')
df['Deposit_Lost']=df['Deposit_Lost'].astype(str)
df['Sex']=df['Sex'].astype(str)
df['Deposit_Lost']=l.fit_transform(df['Deposit_Lost'])
df['Sex']=l.fit_transform(df['Sex'])
#df['Deposit_Lost']

# %% [markdown]
# 1.2) Perform EDA (Check the null values, Data types, shape, Univariate, bivariate analysis). Also check for outliers (4 pts). Interpret the inferences for each

# %% [markdown]
# Lets look at the shape of the dataset

# %%
df.shape
# Out:
# (6446, 45)

# %% [markdown]
# Lets look at the boxplot and try to find the outlier

# %%
import matplotlib.pyplot as plt
import seaborn as sns
f,ax = plt.subplots(4,2, figsize=(30,20))
df.boxplot('Votes',ax=ax[0,0],)
# Out:
# <Axes: >

# %% [markdown]
# Percentage of outliers present in the dataset

# %%
import numpy
Q1 = df['Votes'].quantile(0.25)
Q3 = df['Turnout_Percentage'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# -698.97

# %%
df1=pd.DataFrame(df['Constituency_Name'],df['Votes'])
df1.fillna(0,inplace=True)
df1
# Out:
#        Constituency_Name
# Votes
# 767292                 0
# 410337                 0
# 73731                  0
# 65416                  0
# 33944                  0
# ...                  ...
# 1100             VELLORE
# 574          CHIDAMBARAM
# 238       TIRUVANNAMALAI
# 249437                 0
# 121236                 0
#
# [6446 rows x 1 columns]

# %% [markdown]
# Check for Correlation

# %% [markdown]
# Univariate Analysis

# %%
f,ax = plt.subplots(4,2, figsize=(20,20))
sns.countplot(df.Votes,ax=ax[0,0], palette='crest')
sns.distplot(x=df.Assembly_No, ax=ax[0,1],color='b', hist_kws={"histtype": "step", "linewidth": 2,
                            "alpha": 0.75, "color": "g"})
sns.countplot(df.Contested,ax=ax[1,0],palette='crest')
sns.countplot(df.Electors,ax=ax[1,1],palette='crest')
sns.distplot(df.Margin,ax=ax[2,0],color='b', hist_kws={"": "step", "linewidth": 2,
                            "alpha": 0.75, "color": "g"})
sns.distplot(df.Margin_Percentage,ax=ax[2,1],color='b', hist_kws={"histtype": "step", "linewidth": 2,
                            "alpha": 0.75, "color": "g"})
sns.distplot(df.Position,ax=ax[3,0],color='b',hist_kws={"histtype": "step", "linewidth": 2,
                            "alpha": 0.75, "color": "g"})
sns.countplot(df.Votes,ax=ax[3,1],palette='crest')

plt.show()
# Out:
# <ipython-input-106-a583ed1f90ea>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df.Votes,ax=ax[0,0], palette='crest')
# <ipython-input-106-a583ed1f90ea>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df.Assembly_No, ax=ax[0,1],color='b', hist_kws={"histtype": "step", "linewidth": 2,
# <ipython-input-106-a583ed1f90ea>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df.Contested,ax=ax[1,0],palette='crest')
# <ipython-input-106-a583ed1f90ea>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df.Electors,ax=ax[1,1],palette='crest')
# <ipython-input-106-a583ed1f90ea>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Margin,ax=ax[2,0],color='b', hist_kws={"": "step", "linewidth": 2,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-a583ed1f90ea> in <cell line: 7>()
#       5 sns.countplot(df.Contested,ax=ax[1,0],palette='crest')
#       6 sns.countplot(df.Electors,ax=ax[1,1],palette='crest')
# ----> 7 sns.distplot(df.Margin,ax=ax[2,0],color='b', hist_kws={"": "step", "linewidth": 2,
#       8                             "alpha": 0.75, "color": "g"})
#       9 sns.distplot(df.Margin_Percentage,ax=ax[2,1],color='b', hist_kws={"histtype": "step", "linewidth": 2,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2485         orientation = "horizontal" if vertical else "vertical"
#    2486         hist_color = hist_kws.pop("color", color)
# -> 2487         ax.hist(a, bins, orientation=orientation,
#    2488                 color=hist_color, **hist_kws)
#    2489         if hist_color != color:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6941             if patch:
#    6942                 p = patch[0]
# -> 6943                 p._internal_update(kwargs)
#    6944                 if lbl is not None:
#    6945                     p.set_label(lbl)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1195                     func = getattr(self, f"set_{k}", None)
#    1196                     if not callable(func):
# -> 1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
#    1199                     ret.append(func(v))
#
# AttributeError: Rectangle.set() got an unexpected keyword argument ''

# %% [markdown]
# Bivariate Analysis

# %%
pd.crosstab(df.Party, df.Deposit_Lost,margins=True)
# Out:
# Deposit_Lost   0     1     2   All
# Party
# 0              1     0     0     1
# AAAP           0     0    24    24
# ABHM           0     0     7     7
# ABKMM          0     0     1     1
# ACDP           0     0     7     7
# ...           ..   ...   ...   ...
# VCK            0     5     0     5
# VMMKT          0     0     1     1
# YSP            0     0     2     2
# rpsn           0     0     1     1
# All           78  1082  5286  6446
#
# [168 rows x 4 columns]

# %%
pd.crosstab(df.Party, df.Sex,margins=True)
# Out:
# Sex      0    1     2  3  4   5   All
# Party
# 0        1    0     0  0  0   0     1
# AAAP     0    1    23  0  0   0    24
# ABHM     0    0     7  0  0   0     7
# ABKMM    0    0     1  0  0   0     1
# ACDP     0    0     7  0  0   0     7
# ...    ...  ...   ... .. ..  ..   ...
# VCK      0    0     5  0  0   0     5
# VMMKT    0    0     1  0  0   0     1
# YSP      0    0     2  0  0   0     2
# rpsn     0    0     1  0  0   0     1
# All    140  284  6008  2  1  11  6446
#
# [168 rows x 7 columns]

# %% [markdown]
# 1.3) Encode the data (having string values) for Modelling. Is Scaling necessary here or not? Data Split: Split the data into train and test (70:30)

# %% [markdown]
# Extract the target column into separate vectors for training set and test set
# Encoding the Non Numeric Variables into numeric

# %%
X= pd.get_dummies(df.drop("Votes",axis=1),drop_first=True)
X.astype(int)
print(X.shape)
# Out:
# (6446, 11969)

# %%
X.head()
# Out:
#    Assembly_No  Constituency_No  Year  month  Poll_No  DelimID  Position  Sex  \
# 0           17                1  2019    4.0        0        4         1    2
# 1           17                1  2019    4.0        0        4         2    2
# 2           17                1  2019    4.0        0        4         3    2
# 3           17                1  2019    4.0        0        4         4    1
# 4           17                1  2019    4.0        0        4         5    2
#
#    Valid_Votes   Electors  ...  TCPD_Prof_Second_Desc_Municipality Member  \
# 0      1408189  1946870.0  ...                                      False
# 1      1408189  1946870.0  ...                                      False
# 2      1408189  1946870.0  ...                                      False
# 3      1408189  1946870.0  ...                                      False
# 4      1408189  1946870.0  ...                                      False
#
#    TCPD_Prof_Second_Desc_NGO  TCPD_Prof_Second_Desc_Party Worker  \
# 0                      False                               False
# 1                      False                               False
# 2                      False                               False
# 3                      False                               False
# 4                      False                               False
#
#    TCPD_Prof_Second_Desc_Pastor  TCPD_Prof_Second_Desc_Priest  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    TCPD_Prof_Second_Desc_Principal or Administrator  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    TCPD_Prof_Second_Desc_Qualified Professional  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    TCPD_Prof_Second_Desc_Self-employed  TCPD_Prof_Second_Desc_Shop Keeper  \
# 0                                False                              False
# 1                                False                              False
# 2                                False                              False
# 3                                False                              False
# 4                                False                              False
#
#    TCPD_Prof_Second_Desc_Traditional Medicine
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
# [5 rows x 11969 columns]

# %%
y = df['Deposit_Lost'].astype(int)
y.value_counts()
# Out:
# Deposit_Lost
# 2    5286
# 1    1082
# 0      78
# Name: count, dtype: int64

# %% [markdown]
# Encoding the Target Variables

# %%
y.replace('yes',0,inplace=True)
y.replace('no',1,inplace=True)
y.value_counts()
# Out:
# Deposit_Lost
# 2    5286
# 1    1082
# 0      78
# Name: count, dtype: int64

# %% [markdown]
# Split data into training and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 1)

# %% [markdown]
# 1.4) `Apply Logistic Regression`

# %% [markdown]
# Logistic Regression

# %%
import statsmodels.api as sm
X_train_lr=X_train.copy()
y_train_lr=y_train.copy()
X_train_lr.astype(int)
y_train_lr.astype(int)
X_train_lr_0=sm.add_constant(X_train_lr)
X_train_lr_0.head()
# Out:
#       const  Assembly_No  Constituency_No  Year  month  Poll_No  DelimID  \
# 3740    1.0           12               25  1998    3.0        0        3
# 3973    1.0           11                5  1996    4.0        0        3
# 159     1.0           17                7  2019    4.0        0        4
# 3816    1.0           12               35  1998    3.0        0        3
# 3739    1.0           12               25  1998    3.0        0        3
#
#       Position  Sex  Valid_Votes  ...  \
# 3740         7    2       602499  ...
# 3973        13    2       706830  ...
# 159         10    2      1178060  ...
# 3816         9    2       764917  ...
# 3739         6    2       602499  ...
#
#       TCPD_Prof_Second_Desc_Municipality Member  TCPD_Prof_Second_Desc_NGO  \
# 3740                                      False                      False
# 3973                                      False                      False
# 159                                       False                      False
# 3816                                      False                      False
# 3739                                      False                      False
#
#       TCPD_Prof_Second_Desc_Party Worker  TCPD_Prof_Second_Desc_Pastor  \
# 3740                               False                         False
# 3973                               False                         False
# 159                                False                         False
# 3816                               False                         False
# 3739                               False                         False
#
#       TCPD_Prof_Second_Desc_Priest  \
# 3740                         False
# 3973                         False
# 159                          False
# 3816                         False
# 3739                         False
#
#       TCPD_Prof_Second_Desc_Principal or Administrator  \
# 3740                                             False
# 3973                                             False
# 159                                              False
# 3816                                             False
# 3739                                             False
#
#       TCPD_Prof_Second_Desc_Qualified Professional  \
# 3740                                         False
# 3973                                         False
# 159                                          False
# 3816                                         False
# 3739                                         False
#
#       TCPD_Prof_Second_Desc_Self-employed  TCPD_Prof_Second_Desc_Shop Keeper  \
# 3740                                False                              False
# 3973                                False                              False
# 159                                 False                              False
# 3816                                False                              False
# 3739                                False                              False
#
#       TCPD_Prof_Second_Desc_Traditional Medicine
# 3740                                       False
# 3973                                       False
# 159                                        False
# 3816                                       False
# 3739                                       False
#
# [5 rows x 11970 columns]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
X_train.head()
# Out:
#       Assembly_No  Constituency_No  Year  month  Poll_No  DelimID  Position  \
# 3740           12               25  1998    3.0        0        3         7
# 3973           11                5  1996    4.0        0        3        13
# 159            17                7  2019    4.0        0        4        10
# 3816           12               35  1998    3.0        0        3         9
# 3739           12               25  1998    3.0        0        3         6
#
#       Sex  Valid_Votes   Electors  ...  \
# 3740    2       602499  1079255.0  ...
# 3973    2       706830  1043889.0  ...
# 159     2      1178060  1500016.0  ...
# 3816    2       764917  1203627.0  ...
# 3739    2       602499  1079255.0  ...
#
#       TCPD_Prof_Second_Desc_Municipality Member  TCPD_Prof_Second_Desc_NGO  \
# 3740                                      False                      False
# 3973                                      False                      False
# 159                                       False                      False
# 3816                                      False                      False
# 3739                                      False                      False
#
#       TCPD_Prof_Second_Desc_Party Worker  TCPD_Prof_Second_Desc_Pastor  \
# 3740                               False                         False
# 3973                               False                         False
# 159                                False                         False
# 3816                               False                         False
# 3739                               False                         False
#
#       TCPD_Prof_Second_Desc_Priest  \
# 3740                         False
# 3973                         False
# 159                          False
# 3816                         False
# 3739                         False
#
#       TCPD_Prof_Second_Desc_Principal or Administrator  \
# 3740                                             False
# 3973                                             False
# 159                                              False
# 3816                                             False
# 3739                                             False
#
#       TCPD_Prof_Second_Desc_Qualified Professional  \
# 3740                                         False
# 3973                                         False
# 159                                          False
# 3816                                         False
# 3739                                         False
#
#       TCPD_Prof_Second_Desc_Self-employed  TCPD_Prof_Second_Desc_Shop Keeper  \
# 3740                                False                              False
# 3973                                False                              False
# 159                                 False                              False
# 3816                                False                              False
# 3739                                False                              False
#
#       TCPD_Prof_Second_Desc_Traditional Medicine
# 3740                                       False
# 3973                                       False
# 159                                        False
# 3816                                       False
# 3739                                       False
#
# [5 rows x 11969 columns]

# %%
X_test.head()
# Out:
#       Assembly_No  Constituency_No  Year  month  Poll_No  DelimID  Position  \
# 2663           14                3  2004    4.0        0        3         8
# 386            17               18  2019    4.0        0        4         2
# 6077            7               38  1980    1.0        0        3         8
# 4277           11               22  1996    4.0        0        3        13
# 3196           13                1  1999    9.0        0        3        18
#
#       Sex  Valid_Votes   Electors  ...  \
# 2663    2       934548  1949904.0  ...
# 386     2      1119584  1530014.0  ...
# 6077    2       439140   704399.0  ...
# 4277    2       706553  1067963.0  ...
# 3196    1       879473  2041341.0  ...
#
#       TCPD_Prof_Second_Desc_Municipality Member  TCPD_Prof_Second_Desc_NGO  \
# 2663                                      False                      False
# 386                                       False                      False
# 6077                                      False                      False
# 4277                                      False                      False
# 3196                                      False                      False
#
#       TCPD_Prof_Second_Desc_Party Worker  TCPD_Prof_Second_Desc_Pastor  \
# 2663                               False                         False
# 386                                False                         False
# 6077                               False                         False
# 4277                               False                         False
# 3196                               False                         False
#
#       TCPD_Prof_Second_Desc_Priest  \
# 2663                         False
# 386                          False
# 6077                         False
# 4277                         False
# 3196                         False
#
#       TCPD_Prof_Second_Desc_Principal or Administrator  \
# 2663                                             False
# 386                                              False
# 6077                                             False
# 4277                                             False
# 3196                                             False
#
#       TCPD_Prof_Second_Desc_Qualified Professional  \
# 2663                                         False
# 386                                          False
# 6077                                         False
# 4277                                         False
# 3196                                         False
#
#       TCPD_Prof_Second_Desc_Self-employed  TCPD_Prof_Second_Desc_Shop Keeper  \
# 2663                                False                              False
# 386                                 False                              False
# 6077                                False                              False
# 4277                                False                              False
# 3196                                False                              False
#
#       TCPD_Prof_Second_Desc_Traditional Medicine
# 2663                                       False
# 386                                        False
# 6077                                       False
# 4277                                       False
# 3196                                       False
#
# [5 rows x 11969 columns]

# %%
X_train_lr_2=X_train.drop(['Position','DelimID'],axis=1)
#X_train_lr_2.head()
X_test_lr_2=X_test.drop(['Position','DelimID'],axis=1)
lr_model=lr.fit(X_train_lr_2,y_train)
print("Model Score",lr_model.score(X_train_lr_2,y_train)*100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model Score 94.99113475177306

# %%
lr_train_pred=lr_model.predict(X_train_lr_2)
lr_train_pred_prob=lr_model.predict_proba(X_train_lr_2)
lr_test_pred=lr_model.predict(X_test_lr_2)
lr_test_pred_prob=lr_model.predict_proba(X_test_lr_2)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, roc_curve, roc_auc_score,\
classification_report,f1_score

# %% [markdown]
# Logistic Regression - Confusion Matrix

# %%
#Train confusion and classification
from pylab import rcParams

rcParams['figure.figsize']=(6,4)
sns.heatmap(confusion_matrix(y_train,lr_train_pred), annot = True, fmt='g', cmap="Blues")
lr_train_rep=classification_report(y_train,lr_train_pred,output_dict=True)

lr_train_df=round(pd.DataFrame(lr_train_rep).transpose(), 3)
lr_train_df.head()
# Out:
#            precision  recall  f1-score  support
# 0              0.000   0.000     0.000    60.00
# 1              0.940   0.838     0.886   749.00
# 2              0.953   0.988     0.970  3703.00
# accuracy       0.950   0.950     0.950     0.95
# macro avg      0.631   0.609     0.619  4512.00

# %%
rcParams['figure.figsize']=(6,4)
sns.heatmap(confusion_matrix(y_test,lr_test_pred), annot = True, fmt='g', cmap="Blues")

lr_test_rep=classification_report(y_test,lr_test_pred,output_dict=True)

lr_test_df=round(pd.DataFrame(lr_test_rep).transpose(), 3)
lr_test_df.head()
# Out:
#            precision  recall  f1-score  support
# 0              0.000   0.000     0.000    18.00
# 1              0.945   0.829     0.883   333.00
# 2              0.954   0.986     0.970  1583.00
# accuracy       0.950   0.950     0.950     0.95
# macro avg      0.633   0.605     0.618  1934.00

# %% [markdown]
# 1.5) *Apply::* KNN Model and Naïve Bayes
# Model.Interpret the inferences
# of each model

# %% [markdown]
# K-Nearest Neighbors

# %%
#Plain KNN Model
from sklearn.neighbors import KNeighborsClassifier
KNN_model = KNeighborsClassifier()
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import classification_report, confusion_matrix, recall_score, accuracy_score, precision_score, f1_score

y_train_pred = KNN_model.predict(X_train)
#Train accuracy
model_score = KNN_model.score(X_train,y_train)
print(model_score*100)
print()
# Out:
# 95.16843971631207

# %%
#Train confusion and classification

sns.heatmap(confusion_matrix(y_train,y_train_pred), annot = True, fmt='g', cmap="Blues")

KNN1=classification_report(y_train,y_train_pred,output_dict=True)


KNN1_df=round(pd.DataFrame(KNN1).transpose(), 3)
KNN1_df.head()
# Out:
#            precision  recall  f1-score   support
# 0              0.000   0.000     0.000    60.000
# 1              0.947   0.838     0.890   749.000
# 2              0.953   0.990     0.971  3703.000
# accuracy       0.952   0.952     0.952     0.952
# macro avg      0.633   0.609     0.620  4512.000

# %%
KNN1_acc = KNN1_df.iloc[2,0]
KNN1_acc
# Out:
# 0.953

# %%
#predict on test data
y_test_pred = KNN_model.predict(X_test)
print(KNN_model.score(X_test, y_test))
# Out:
# 0.9477766287487074

# %%
sns.heatmap(confusion_matrix(y_test,y_test_pred), annot = True, fmt='g', cmap="Blues")
KNN1_1=classification_report(y_test,y_test_pred,output_dict=True)
KNN1_1_df=round(pd.DataFrame(KNN1_1).transpose(), 3)
KNN1_1_acc = KNN1_1_df.iloc[2,0]
KNN1_1_df
# Out:
#               precision  recall  f1-score   support
# 0                 0.000   0.000     0.000    18.000
# 1                 0.934   0.811     0.868   333.000
# 2                 0.951   0.987     0.969  1583.000
# accuracy          0.948   0.948     0.948     0.948
# macro avg         0.628   0.599     0.612  1934.000
# weighted avg      0.939   0.948     0.942  1934.000

# %%
#Iteration 2: Scale the numbers
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_train=pd.DataFrame(X_train,columns=X.columns)

X_test = sc.transform(X_test)
X_test=pd.DataFrame(X_test,columns=X.columns)
# call and fit the model on train data
KNN_model2 = KNeighborsClassifier()
KNN_model2.fit(X_train,y_train)
y_train_pred = KNN_model2.predict(X_train)

# %%
#Train performance
model_score = KNN_model.score(X_train,y_train)
print(model_score)
#Train confusion and classification
sns.heatmap(confusion_matrix(y_train,y_train_pred), annot = True, fmt='g', cmap="Blues")

KNN2=classification_report(y_train,y_train_pred,output_dict=True)
KNN2_df=round(pd.DataFrame(KNN2).transpose(),3)
KNN2_acc = KNN2_df.iloc[2,0]
KNN2_df
# Out:
# 0.8207003546099291
#               precision  recall  f1-score  support
# 0                 0.013   1.000     0.026    60.00
# 1                 0.897   0.035     0.067   749.00
# 2                 1.000   0.002     0.003  3703.00
# accuracy          0.020   0.020     0.020     0.02
# macro avg         0.637   0.345     0.032  4512.00
# weighted avg      0.970   0.020     0.014  4512.00

# %%
#Test prediction and performance
y_test_pred = KNN_model.predict(X_test)
print(KNN_model2.score(X_test, y_test))
print(classification_report(y_test,y_test_pred))

sns.heatmap(confusion_matrix(y_test,y_test_pred), annot = True, fmt='g', cmap="Blues")

KNN2_1=classification_report(y_test,y_test_pred,output_dict=True)
KNN2_1_df=round(pd.DataFrame(KNN2_1).transpose(),3)
KNN2_1_acc = KNN2_1_df.iloc[2,0]
KNN2_1_df
# Out:
# 0.010341261633919338
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.00      0.00      0.00       333
#            2       0.82      1.00      0.90      1583
#
#     accuracy                           0.82      1934
#    macro avg       0.27      0.33      0.30      1934
# weighted avg       0.67      0.82      0.74      1934
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score   support
# 0                 0.000   0.000     0.000    18.000
# 1                 0.000   0.000     0.000   333.000
# 2                 0.819   1.000     0.900  1583.000
# accuracy          0.819   0.819     0.819     0.819
# macro avg         0.273   0.333     0.300  1934.000
# weighted avg      0.670   0.819     0.737  1934.000

# %%
#Iteration 3: find the optimum k value
ac_scores_train = []
ac_scores_test = []

for k in range(1,20,2):
  knn3 = KNeighborsClassifier(n_neighbors = k)
  knn3.fit(X_train,y_train)
  #Evaluation of Train
  ac_train = knn3.score(X_train,y_train)
  ac_scores_train.append(ac_train)
  #Evaluation of Test
  ac_test = knn3.score(X_test,y_test)
  ac_scores_test.append(ac_test)

# %%
ac_scores_test
# Out:
# [0.12719751809720786,
#  0.021199586349534644,
#  0.010341261633919338,
#  0.00982419855222337,
#  0.009307135470527405,
#  0.009307135470527405,
#  0.009307135470527405,
#  0.009307135470527405,
#  0.009307135470527405,
#  0.009307135470527405]

# %%
plt.plot(range(1,20,2), ac_scores_train)
plt.plot(range(1,20,2), ac_scores_test)

# %%
KNN_model3 = KNeighborsClassifier(n_neighbors=16)
KNN_model3.fit(X_train,y_train)

y_train_pred = KNN_model3.predict(X_train)
#Train accuracy
model_score = KNN_model3.score(X_train,y_train)
print(model_score)
print()

#Train confusion and classification

sns.heatmap(confusion_matrix(y_train,y_train_pred), annot = True, fmt='g', cmap="Blues")

#print(metrics.classification_report(y_train,y_train_pred))
KNN3=classification_report(y_train,y_train_pred,output_dict=True)

KNN3_df=round(pd.DataFrame(KNN3).transpose(),3)
KNN3_acc = KNN3_df.iloc[2,0]
KNN3_df
# Out:
# 0.013297872340425532
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score   support
# 0                 0.013   1.000     0.026    60.000
# 1                 0.000   0.000     0.000   749.000
# 2                 0.000   0.000     0.000  3703.000
# accuracy          0.013   0.013     0.013     0.013
# macro avg         0.004   0.333     0.009  4512.000
# weighted avg      0.000   0.013     0.000  4512.000

# %%
#predict on test data
y_train_pred = KNN_model3.predict(X_train)
y_test_pred = KNN_model3.predict(X_test)
print(KNN_model3.score(X_test, y_test))

#print(metrics.classification_report(y_test,y_test_pred))
sns.heatmap(confusion_matrix(y_test,y_test_pred), annot = True, fmt='g', cmap="Blues")

KNN3_1=classification_report(y_test,y_test_pred,output_dict=True)

KNN3_1_df=round(pd.DataFrame(KNN3_1).transpose(),3)
KNN3_1_acc = KNN3_1_df.iloc[2,0]
KNN3_1_df
# Out:
# 0.009307135470527405
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score   support
# 0                 0.009   1.000     0.018    18.000
# 1                 0.000   0.000     0.000   333.000
# 2                 0.000   0.000     0.000  1583.000
# accuracy          0.009   0.009     0.009     0.009
# macro avg         0.003   0.333     0.006  1934.000
# weighted avg      0.000   0.009     0.000  1934.000

# %% [markdown]
# 1.6)**Naive** Bayes

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
NB_model = GaussianNB()
NB2_model = BernoulliNB()
NB3_model = MultinomialNB()

# %%
NB_model.fit(X_train, y_train)
print(NB_model.score(X_train, y_train))
NB_ypred=NB_model.predict(X_train)
print(classification_report(y_train,NB_ypred))
NB_df=classification_report(y_train,NB_ypred,output_dict=True)
sns.heatmap(confusion_matrix(y_train,NB_ypred), annot = True, fmt='g', cmap="Blues")

NB_df=round(pd.DataFrame(NB_df).transpose(), 3)
NB_df.head()
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       1.00      1.00      1.00       749
#            2       1.00      1.00      1.00      3703
#
#     accuracy                           1.00      4512
#    macro avg       1.00      1.00      1.00      4512
# weighted avg       1.00      1.00      1.00      4512
#            precision  recall  f1-score  support
# 0                1.0     1.0       1.0     60.0
# 1                1.0     1.0       1.0    749.0
# 2                1.0     1.0       1.0   3703.0
# accuracy         1.0     1.0       1.0      1.0
# macro avg        1.0     1.0       1.0   4512.0

# %%
NB_df_acc = NB_df.iloc[2,0]
NB_df_acc
# Out:
# 1.0

# %%
# Test for Gaussian Model
NB_ypred_1=NB_model.predict(X_test)
#print(classification_report(y_test,NB_ypred_1))
NB_df_1=classification_report(y_test,NB_ypred_1,output_dict=True)
sns.heatmap(confusion_matrix(y_test,NB_ypred_1), annot = True, fmt='g', cmap="Blues")
NB_df_1=round(pd.DataFrame(NB_df_1).transpose(), 3)
NB_df_1.head()
# Out:
#            precision  recall  f1-score   support
# 0              1.000   1.000     1.000    18.000
# 1              0.957   0.931     0.944   333.000
# 2              0.986   0.991     0.988  1583.000
# accuracy       0.981   0.981     0.981     0.981
# macro avg      0.981   0.974     0.977  1934.000

# %%
NB_df_1_acc = NB_df_1.iloc[2,0]
NB_df_1_acc
# Out:
# 0.986

# %%
# Train for Bernoulli Model
NB2_model.fit(X_train, y_train)
print(NB2_model.score(X_train, y_train))
NB2_ypred=NB2_model.predict(X_train)
#print(classification_report(y_train,NB2_ypred))
sns.heatmap(confusion_matrix(y_train,NB2_ypred), annot = True, fmt='g', cmap="Blues")

NB2_df=round(pd.DataFrame(classification_report(y_train,NB2_ypred,output_dict=True)).transpose(), 3)
NB2_df.head()
# Out:
# 0.9809397163120568
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#            precision  recall  f1-score   support
# 0              0.000   0.000     0.000    60.000
# 1              0.971   0.995     0.983   749.000
# 2              0.983   0.994     0.988  3703.000
# accuracy       0.981   0.981     0.981     0.981
# macro avg      0.651   0.663     0.657  4512.000

# %%
NB2_df_acc = NB2_df.iloc[2,0]
NB2_df_acc
# Out:
# 0.983

# %%
# Test for Bernoulli Model
NB2_ypred_1=NB2_model.predict(X_test)
NB2_df_1 = classification_report(y_test, NB2_ypred_1, output_dict=True)
sns.heatmap(confusion_matrix(y_test, NB2_ypred_1), annot = True, fmt='g', cmap="Blues")
NB2_df_1 = round(pd.DataFrame(NB2_df_1).transpose(), 3)
NB2_df_1.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#            precision  recall  f1-score   support
# 0              0.000   0.000     0.000    18.000
# 1              0.976   0.991     0.984   333.000
# 2              0.987   0.995     0.991  1583.000
# accuracy       0.985   0.985     0.985     0.985
# macro avg      0.654   0.662     0.658  1934.000

# %%
NB2_df_1_acc = NB2_df_1.iloc[2,0]
NB2_df_1_acc
# Out:
# 0.987

# %%
# Train for Multinomial Model
NB3_model.fit(abs(X_train), abs(y_train))
print(NB3_model.score(X_train, y_train))
NB3_ypred=NB3_model.predict(X_train)
#print(classification_report(y_train,NB2_ypred))
sns.heatmap(confusion_matrix(y_train,NB3_ypred), annot = True, fmt='g', cmap="Blues")

NB3_df=round(pd.DataFrame(classification_report(y_train,NB3_ypred,output_dict=True)).transpose(), 3)
NB3_df.head()
# Out:
# 0.981604609929078
#            precision  recall  f1-score   support
# 0              0.952   1.000     0.976    60.000
# 1              0.903   1.000     0.949   749.000
# 2              1.000   0.978     0.989  3703.000
# accuracy       0.982   0.982     0.982     0.982
# macro avg      0.952   0.993     0.971  4512.000

# %%
# Test for Multinomial Model
NB3_ypred_1=NB3_model.predict(X_test)
NB3_df_1 = classification_report(y_test, NB3_ypred_1, output_dict=True)
sns.heatmap(confusion_matrix(y_test, NB2_ypred_1), annot = True, fmt='g', cmap="Blues")
NB3_df_1 = round(pd.DataFrame(NB3_df_1).transpose(), 3)
NB3_df_1.head()
# Out:
#            precision  recall  f1-score   support
# 0              0.101   1.000     0.183    18.000
# 1              0.198   0.991     0.330   333.000
# 2              0.978   0.055     0.104  1583.000
# accuracy       0.225   0.225     0.225     0.225
# macro avg      0.425   0.682     0.206  1934.000

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# 1.7) Model Tuning (3 pts) , Bagging ( 3 pts) and Boosting
# Boosting
# Adaboost Classifier

# %%
# Training the Adaboost Model
from sklearn.ensemble import AdaBoostClassifier
ADB_Model = AdaBoostClassifier(n_estimators=100, random_state=1)
ADB_Model.fit(X_train,y_train)
ADB_Model.predict(X_train)
print(ADB_Model.score(X_train, y_train))
ADB_df = round(pd.DataFrame(classification_report(y_train, ADB_Model.predict(X_train), output_dict=True)).transpose(),3)
sns.heatmap(confusion_matrix(y_train, ADB_Model.predict(X_train)), annot = True, fmt='g', cmap="Blues")
ADB_df.head()
# Out:
# 1.0
#            precision  recall  f1-score  support
# 0                1.0     1.0       1.0     60.0
# 1                1.0     1.0       1.0    749.0
# 2                1.0     1.0       1.0   3703.0
# accuracy         1.0     1.0       1.0      1.0
# macro avg        1.0     1.0       1.0   4512.0

# %%
ADB_df_acc = ADB_df.iloc[2,0]
ADB_df_acc
# Out:
# 1.0

# %%
# Testing the Adaboost Model
ADB_pred = ADB_Model.predict(X_test)
#print(ADB_Model.score(X_test,y_test))
ADB_df_1 = round(pd.DataFrame(classification_report(y_test, ADB_Model.predict(X_test), output_dict=True)).transpose(),3)
sns.heatmap(confusion_matrix(y_test, ADB_Model.predict(X_test)), annot = True, fmt='g', cmap="Blues")
ADB_df_1.head()
# Out:
#            precision  recall  f1-score  support
# 0                1.0     1.0       1.0     18.0
# 1                1.0     1.0       1.0    333.0
# 2                1.0     1.0       1.0   1583.0
# accuracy         1.0     1.0       1.0      1.0
# macro avg        1.0     1.0       1.0   1934.0

# %%
ADB_df_1_acc = ADB_df_1.iloc[2,0]
ADB_df_1_acc
# Out:
# 1.0

# %% [markdown]
# Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier()
# Training the Gradient Boost Model
gbcl.fit(X_train, y_train)
GB_ytrain_pred = gbcl.predict(X_train)
#print(gbcl.score(X_train, y_train))
GB_df= classification_report(y_train, GB_ytrain_pred, output_dict=True)
sns.heatmap(confusion_matrix(y_train, GB_ytrain_pred), annot = True, fmt='g', cmap="Blues")

GB_df=round(pd.DataFrame(GB_df).transpose(),3)
GB_df.head()
# Out:
#            precision  recall  f1-score  support
# 0                1.0     1.0       1.0     60.0
# 1                1.0     1.0       1.0    749.0
# 2                1.0     1.0       1.0   3703.0
# accuracy         1.0     1.0       1.0      1.0
# macro avg        1.0     1.0       1.0   4512.0

# %%
# Train Accuracy Gradient Boosting
GB_df_acc = GB_df.iloc[2,0]
GB_df_acc
# Out:
# 1.0

# %%
# Testing the Gradiant Boosting Model
GB_ytest_pred = gbcl.predict(X_test)
GB_df_1 = round(pd.DataFrame(classification_report(y_test, GB_ytest_pred, output_dict=True)).transpose(),3)
sns.heatmap(confusion_matrix(y_test, GB_ytest_pred), annot = True, fmt='g', cmap="Blues")
GB_df_1.head()
# Out:
#            precision  recall  f1-score  support
# 0                1.0     1.0       1.0     18.0
# 1                1.0     1.0       1.0    333.0
# 2                1.0     1.0       1.0   1583.0
# accuracy         1.0     1.0       1.0      1.0
# macro avg        1.0     1.0       1.0   1934.0

# %%
# Test Accuracy Gradient Boosting
GBTest_acc = GB_df_1.iloc[2,0]
GBTest_acc
# Out:
# 1.0

# %% [markdown]
# 1.8 Performance Metrics:
#
#
#  Compare all models on the basis of the performance metrics in a structured tabular manner.

# %%
#KNN1
KNN1_train_model0_precision=round(KNN1_df["precision"][0],2)
KNN1_train_model0_recall=round(KNN1_df["recall"][0],2)
KNN1_train_model0_f1=round(KNN1_df["f1-score"][0],2)
KNN1_train_model0_acc=round(KNN1_df["f1-score"][2],2)

KNN1_test_model0_precision=round(KNN1_1_df["precision"][0],2)
KNN1_test_model0_recall=round(KNN1_1_df["recall"][0],2)
KNN1_test_model0_f1=round(KNN1_1_df["f1-score"][0],2)
KNN1_test_model0_acc=round(KNN1_1_df["f1-score"][2],2)


#KNN2
KNN2_train_model0_precision=round(KNN2_df["precision"][0],2)
KNN2_train_model0_recall=round(KNN2_df["recall"][0],2)
KNN2_train_model0_f1=round(KNN2_df["f1-score"][0],2)
KNN2_train_model0_acc=round(KNN2_df["f1-score"][2],2)

KNN2_test_model0_precision=round(KNN2_1_df["precision"][0],2)
KNN2_test_model0_recall=round(KNN2_1_df["recall"][0],2)
KNN2_test_model0_f1=round(KNN2_1_df["f1-score"][0],2)
KNN2_test_model0_acc=round(KNN2_1_df["f1-score"][2],2)


#KNN3
KNN3_train_model0_precision=round(KNN3_df["precision"][0],2)
KNN3_train_model0_recall=round(KNN3_df["recall"][0],2)
KNN3_train_model0_f1=round(KNN3_df["f1-score"][0],2)
KNN3_train_model0_acc=round(KNN3_df["f1-score"][2],2)

KNN3_test_model0_precision=round(KNN3_1_df["precision"][0],2)
KNN3_test_model0_recall=round(KNN3_1_df["recall"][0],2)
KNN3_test_model0_f1=round(KNN3_1_df["f1-score"][0],2)
KNN3_test_model0_acc=round(KNN3_1_df["f1-score"][2],2)



#Naive Bayes Gaussian Model
NB_train_model0_precision=round(NB_df["precision"][0],2)
NB_train_model0_recall=round(NB_df["recall"][0],2)
NB_train_model0_f1=round(NB_df["f1-score"][0],2)
NB_train_model0_acc=round(NB_df["f1-score"][2],2)

NB_test_model0_precision=round(NB_df_1["precision"][0],2)
NB_test_model0_recall=round(NB_df_1["recall"][0],2)
NB_test_model0_f1=round(NB_df_1["f1-score"][0],2)
NB_test_model0_acc=round(NB_df_1["f1-score"][2],2)

#Naive Bayes Bernouli Model
NB2_train_model0_precision=round(NB2_df["precision"][0],2)
NB2_train_model0_recall=round(NB2_df["recall"][0],2)
NB2_train_model0_f1=round(NB2_df["f1-score"][0],2)
NB2_train_model0_acc=round(NB2_df["f1-score"][2],2)

NB2_test_model0_precision=round(NB2_df_1["precision"][0],2)
NB2_test_model0_recall=round(NB2_df_1["recall"][0],2)
NB2_test_model0_f1=round(NB2_df_1["f1-score"][0],2)
NB2_test_model0_acc=round(NB2_df_1["f1-score"][2],2)

# %%
index=['Accuracy', 'Recall','Precision','F1 Score']
data = pd.DataFrame(({
            'KNN1 Train':[KNN1_train_model0_acc,KNN1_train_model0_recall,KNN1_train_model0_precision,KNN1_train_model0_f1],
            'KNN1 Test':[KNN1_test_model0_acc,KNN1_test_model0_recall,KNN1_test_model0_precision,KNN1_test_model0_f1],

            'KNN2 Train':[KNN2_train_model0_acc,KNN2_train_model0_recall,KNN2_train_model0_precision,KNN2_train_model0_f1],
            'KNN2 Test':[KNN2_test_model0_acc,KNN2_test_model0_recall,KNN2_test_model0_precision,KNN2_test_model0_f1],


            'KNN3 Train':[KNN3_train_model0_acc,KNN3_train_model0_recall,KNN3_train_model0_precision,KNN3_train_model0_f1],
            'KNN3 Test':[KNN3_test_model0_acc,KNN3_test_model0_recall,KNN3_test_model0_precision,KNN3_test_model0_f1],

            'NB Train':[NB_train_model0_acc,NB_train_model0_recall,NB_train_model0_precision,NB_train_model0_f1],
            'NB Test':[NB_test_model0_acc,NB_test_model0_recall,NB_test_model0_precision,NB_test_model0_f1],

            'NB2 Train':[NB2_train_model0_acc,NB2_train_model0_recall,NB2_train_model0_precision,NB2_train_model0_f1],
            'NB2 Test':[NB2_test_model0_acc,NB2_test_model0_recall,NB2_test_model0_precision,NB2_test_model0_f1]
            }))
print(round(data,2))
# Out:
#    KNN1 Train  KNN1 Test  KNN2 Train  KNN2 Test  KNN3 Train  KNN3 Test  \
# 0        0.97       0.97        0.00        0.9        0.00       0.00
# 1        0.00       0.00        1.00        0.0        1.00       1.00
# 2        0.00       0.00        0.01        0.0        0.01       0.01
# 3        0.00       0.00        0.03        0.0        0.03       0.02
#
#    NB Train  NB Test  NB2 Train  NB2 Test
# 0       1.0     0.99       0.99      0.99
# 1       1.0     1.00       0.00      0.00
# 2       1.0     1.00       0.00      0.00
# 3       1.0     1.00       0.00      0.00

# %% [markdown]
# 1.9) Based on your analysis and working on the business problem, detail out appropriate insights and recommendations to help the management solve the business objective

# %%
KNN_model3.fit(X,y)
y_final_pred = KNN_model3.predict(X)
print(KNN_model3.score(X,y))

#print(metrics.classification_report(y_test,y_test_pred))
sns.heatmap(confusion_matrix(y,y_final_pred), annot = True, fmt='g', cmap="Blues")

KNN3_final=classification_report(y,y_final_pred,output_dict=True)

KNN3_final_df=round(pd.DataFrame(KNN3_final).transpose(),3)
KNN3_final_acc = KNN3_final_df.iloc[2,0]
KNN3_final_df
# Out:
# 0.9472541110766367
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score   support
# 0                 0.000   0.000     0.000    78.000
# 1                 0.939   0.811     0.870  1082.000
# 2                 0.949   0.989     0.969  5286.000
# accuracy          0.947   0.947     0.947     0.947
# macro avg         0.629   0.600     0.613  6446.000
# weighted avg      0.936   0.947     0.940  6446.000
